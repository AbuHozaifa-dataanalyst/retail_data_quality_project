# %%
import pandas as pd
import numpy as np
from pathlib import Path

np.random.seed(42)

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_DIR = PROJECT_ROOT / "data" / "raw"
CLEANED_DIR = PROJECT_ROOT / "data" / "cleaned"
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"

RAW_DIR.mkdir(parents=True, exist_ok=True)
CLEANED_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print("Project root:", PROJECT_ROOT)
print("Raw data folder:", RAW_DIR)
# Out:
# Project root: d:\GitHub\retail_data_quality_project
# Raw data folder: d:\GitHub\retail_data_quality_project\data\raw

# %%
categories = {
    "Electronics": ["Mobile", "Laptop", "Audio", "Accessories"],
    "Home Appliances": ["Kitchen", "Cleaning", "Cooling"],
    "Fashion": ["Men", "Women", "Kids"],
    "Beauty": ["Skincare", "Haircare", "Fragrance"],
    "Sports": ["Fitness", "Outdoor", "Sportswear"],
    "Grocery": ["Beverages", "Snacks", "Pantry"],
    "Home & Living": ["Furniture", "Decor", "Bedding"]
}

brands = [
    "Samsung",
    "Apple",
    "Sony",
    "LG",
    "Philips",
    "Nike",
    "Adidas",
    "P&G",
    "L'Oreal",
    "Nestle",
    "IKEA",
    "Generic"
]

# %%
cities = [
    "Riyadh",
    "Jeddah",
    "Dammam",
    "Khobar",
    "Mecca",
    "Medina",
    "Taif"
]

city_regions = {
    "Riyadh": "Central",
    "Jeddah": "Western",
    "Dammam": "Eastern",
    "Khobar": "Eastern",
    "Mecca": "Western",
    "Medina": "Western",
    "Taif": "Western"
}

# %%
store_data = []

store_types = ["Mall", "Standalone", "Hypermarket"]

for i in range(1, 21):
    city = np.random.choice(cities)

    store_data.append({
        "store_id": f"S{i:03d}",
        "store_name": f"GulfMart {city} {i:02d}",
        "city": city,
        "region": city_regions[city],
        "store_type": np.random.choice(store_types)
    })

dim_store = pd.DataFrame(store_data)

dim_store.head()
# Out:
#   store_id          store_name    city   region   store_type
# 0     S001    GulfMart Taif 01    Taif  Western         Mall
# 1     S002    GulfMart Taif 02    Taif  Western  Hypermarket
# 2     S003   GulfMart Mecca 03   Mecca  Western         Mall
# 3     S004    GulfMart Taif 04    Taif  Western   Standalone
# 4     S005  GulfMart Dammam 05  Dammam  Eastern  Hypermarket

# %%
dim_store.to_csv(RAW_DIR / "dim_store.csv", index=False)

# %%
product_templates = {
    "Mobile": [
        "Smartphone",
        "5G Smartphone",
        "Budget Smartphone",
        "Premium Smartphone"
    ],
    "Laptop": [
        "Laptop",
        "Business Laptop",
        "Gaming Laptop",
        "Ultrabook"
    ],
    "Audio": [
        "Wireless Headphones",
        "Bluetooth Speaker",
        "Earbuds",
        "Soundbar"
    ],
    "Accessories": [
        "Phone Case",
        "Power Bank",
        "USB Cable",
        "Wireless Charger"
    ],
    "Kitchen": [
        "Air Fryer",
        "Blender",
        "Coffee Maker",
        "Microwave"
    ],
    "Cleaning": [
        "Vacuum Cleaner",
        "Steam Cleaner",
        "Robot Vacuum"
    ],
    "Cooling": [
        "Air Conditioner",
        "Fan",
        "Air Cooler"
    ],
    "Men": [
        "Men's Shirt",
        "Men's Jeans",
        "Men's Jacket",
        "Men's T-Shirt"
    ],
    "Women": [
        "Women's Dress",
        "Women's Jeans",
        "Women's Jacket",
        "Women's T-Shirt"
    ],
    "Kids": [
        "Kids T-Shirt",
        "Kids Jeans",
        "Kids Jacket",
        "Kids Shoes"
    ],
    "Skincare": [
        "Face Cream",
        "Moisturizer",
        "Cleanser",
        "Sunscreen"
    ],
    "Haircare": [
        "Shampoo",
        "Conditioner",
        "Hair Mask"
    ],
    "Fragrance": [
        "Perfume",
        "Eau de Toilette",
        "Body Mist"
    ],
    "Fitness": [
        "Yoga Mat",
        "Dumbbell Set",
        "Exercise Bike",
        "Treadmill"
    ],
    "Outdoor": [
        "Camping Tent",
        "Hiking Backpack",
        "Camping Chair"
    ],
    "Sportswear": [
        "Running Shoes",
        "Training Shoes",
        "Sports T-Shirt",
        "Sports Shorts"
    ],
    "Beverages": [
        "Mineral Water",
        "Juice",
        "Soft Drink",
        "Energy Drink"
    ],
    "Snacks": [
        "Potato Chips",
        "Chocolate",
        "Biscuits",
        "Nuts"
    ],
    "Pantry": [
        "Rice",
        "Pasta",
        "Cooking Oil",
        "Cereal"
    ],
    "Furniture": [
        "Office Chair",
        "Coffee Table",
        "Bookshelf",
        "Sofa"
    ],
    "Decor": [
        "Table Lamp",
        "Wall Clock",
        "Picture Frame",
        "Cushion"
    ],
    "Bedding": [
        "Bed Sheet Set",
        "Pillow",
        "Blanket",
        "Comforter"
    ]
}

# %%
product_data = []

subcategory_list = [
    (category, subcategory)
    for category, subcategories in categories.items()
    for subcategory in subcategories
]

for i in range(1, 501):

    category, subcategory = subcategory_list[
        np.random.randint(len(subcategory_list))
    ]

    brand = np.random.choice(brands)

    template = np.random.choice(
        product_templates[subcategory]
    )

    product_name = f"{brand} {template} {i:03d}"

    unit_cost = round(
        np.random.uniform(20, 3000),
        2
    )

    markup = np.random.uniform(1.15, 1.60)

    selling_price = round(
        unit_cost * markup,
        2
    )

    product_data.append({
        "product_id": f"P{i:04d}",
        "product_name": product_name,
        "category": category,
        "subcategory": subcategory,
        "brand": brand,
        "unit_cost": unit_cost,
        "selling_price": selling_price
    })

dim_product = pd.DataFrame(product_data)

dim_product.head()
# Out:
#   product_id               product_name       category subcategory    brand  \
# 0      P0001      L'Oreal Bookshelf 001  Home & Living   Furniture  L'Oreal
# 1      P0002   Adidas Women's Jeans 002        Fashion       Women   Adidas
# 2      P0003    Nestle Potato Chips 003        Grocery      Snacks   Nestle
# 3      P0004  Generic Camping Chair 004         Sports     Outdoor  Generic
# 4      P0005       Samsung Soundbar 005    Electronics       Audio  Samsung
#
#    unit_cost  selling_price
# 0    2582.62        3760.65
# 1    2847.68        4512.25
# 2      67.58          84.74
# 3    1837.79        2802.52
# 4     563.06         838.91

# %%
dim_product.to_csv(RAW_DIR / "dim_product.csv", index=False)

# %%
first_names = [
    "Ahmed",
    "Mohammed",
    "Abdullah",
    "Omar",
    "Khalid",
    "Faisal",
    "Saad",
    "Yousef",
    "Ibrahim",
    "Hassan",
    "Sara",
    "Fatimah",
    "Nora",
    "Maha",
    "Aisha",
    "Reem",
    "Huda",
    "Lina",
    "Maryam",
    "Amal"
]

last_names = [
    "Ali",
    "Hassan",
    "Ahmed",
    "Khan",
    "Rahman",
    "Saeed",
    "Ibrahim",
    "Mahmoud",
    "Saleh",
    "Abdullah",
    "Ansari",
    "Farooq",
    "Malik",
    "Yousuf",
    "Al-Qahtani"
]

# %%
customer_data = []

for i in range(1, 5001):

    gender = np.random.choice(
        ["Male", "Female"],
        p=[0.60, 0.40]
    )

    first_name = np.random.choice(first_names)
    last_name = np.random.choice(last_names)

    customer_name = f"{first_name} {last_name}"

    age = np.random.randint(18, 71)

    city = np.random.choice(cities)

    customer_segment = np.random.choice(
        ["Premium", "Standard", "Value"],
        p=[0.15, 0.55, 0.30]
    )

    customer_data.append({
        "customer_id": f"C{i:05d}",
        "customer_name": customer_name,
        "gender": gender,
        "age": age,
        "city": city,
        "customer_segment": customer_segment
    })

dim_customer = pd.DataFrame(customer_data)

dim_customer.head()
# Out:
#   customer_id  customer_name  gender  age    city customer_segment
# 0      C00001   Maha Mahmoud    Male   27  Medina         Standard
# 1      C00002  Faisal Farooq  Female   26   Mecca            Value
# 2      C00003  Lina Abdullah    Male   60  Riyadh         Standard
# 3      C00004     Saad Saeed    Male   32  Jeddah            Value
# 4      C00005  Aisha Ibrahim    Male   38  Jeddah            Value

# %%
dim_customer.to_csv(RAW_DIR / "dim_customer.csv", index=False)

# %%
N_TRANSACTIONS = 120_000

print(f"Generating {N_TRANSACTIONS:,} transactions")
# Out:
# Generating 120,000 transactions

# %%
date_range = pd.date_range(
    start="2024-01-01",
    end="2025-12-31",
    freq="D"
)

transaction_dates = np.random.choice(
    date_range,
    size=N_TRANSACTIONS
)

# %%
transaction_product_ids = np.random.choice(
    dim_product["product_id"],
    size=N_TRANSACTIONS
)

# %%
transaction_product_ids = np.random.choice(
    dim_product["product_id"],
    size=N_TRANSACTIONS
)

# %%
transaction_customer_ids = np.random.choice(
    dim_customer["customer_id"],
    size=N_TRANSACTIONS
)

# %%
transaction_store_ids = np.random.choice(
    dim_store["store_id"],
    size=N_TRANSACTIONS
)

# %%
payment_methods = [
    "Card",
    "Cash",
    "Mada",
    "Apple Pay",
    "STC Pay"
]

# %%
transaction_payment_methods = np.random.choice(
    payment_methods,
    size=N_TRANSACTIONS,
    p=[0.35, 0.15, 0.25, 0.15, 0.10]
)

# %%
sales_channels = [
    "Store",
    "E-commerce"
]

# %%
transaction_channels = np.random.choice(
    sales_channels,
    size=N_TRANSACTIONS,
    p=[0.70, 0.30]
)

# %%
quantities = np.random.poisson(
    lam=2,
    size=N_TRANSACTIONS
) + 1

quantities = np.clip(
    quantities,
    1,
    10
)

# %%
product_lookup = dim_product[
    [
        "product_id",
        "unit_cost",
        "selling_price"
    ]
].copy()

# %%
transactions = pd.DataFrame({
    "transaction_id": [
        f"T{i:06d}"
        for i in range(1, N_TRANSACTIONS + 1)
    ],
    "transaction_date": transaction_dates,
    "customer_id": transaction_customer_ids,
    "product_id": transaction_product_ids,
    "store_id": transaction_store_ids,
    "quantity": quantities,
    "payment_method": transaction_payment_methods,
    "sales_channel": transaction_channels
})

# %%
transactions = transactions.merge(
    product_lookup,
    on="product_id",
    how="left"
)

# %%
price_variation = np.random.uniform(
    0.95,
    1.05,
    size=N_TRANSACTIONS
)

transactions["unit_price"] = (
    transactions["selling_price"] * price_variation
).round(2)

# %%
transactions["gross_sales"] = (
    transactions["quantity"]
    * transactions["unit_price"]
).round(2)

# %%
transactions["gross_sales"] = (
    transactions["quantity"]
    * transactions["unit_price"]
).round(2)

# %%
discount_rate = np.random.choice(
    [0, 0.05, 0.10, 0.15, 0.20],
    size=N_TRANSACTIONS,
    p=[0.45, 0.25, 0.18, 0.08, 0.04]
)

# %%
transactions["discount_amount"] = (
    transactions["gross_sales"]
    * discount_rate
).round(2)

# %%
transactions["net_sales"] = (
    transactions["gross_sales"]
    - transactions["discount_amount"]
).round(2)

# %%
transactions["cost_amount"] = (
    transactions["quantity"]
    * transactions["unit_cost"]
).round(2)

# %%
transactions["profit_amount"] = (
    transactions["net_sales"]
    - transactions["cost_amount"]
).round(2)

# %%
transactions["gross_margin_pct"] = np.where(
    transactions["net_sales"] != 0,
    (
        transactions["profit_amount"]
        / transactions["net_sales"]
        * 100
    ),
    np.nan
)

transactions["gross_margin_pct"] = (
    transactions["gross_margin_pct"]
    .round(2)
)

# %%
transactions = transactions.drop(
    columns=["selling_price"]
)

# %%
transactions = transactions[
    [
        "transaction_id",
        "transaction_date",
        "customer_id",
        "product_id",
        "store_id",
        "quantity",
        "unit_price",
        "discount_amount",
        "gross_sales",
        "net_sales",
        "unit_cost",
        "cost_amount",
        "profit_amount",
        "gross_margin_pct",
        "payment_method",
        "sales_channel"
    ]
]

# %%
gross_sales_check = (
    transactions["quantity"]
    * transactions["unit_price"]
).round(2)

print(
    np.isclose(
        transactions["gross_sales"],
        gross_sales_check
    ).all()
)
# Out:
# True

# %%
net_sales_check = (
    transactions["gross_sales"]
    - transactions["discount_amount"]
).round(2)

print(
    np.isclose(
        transactions["net_sales"],
        net_sales_check
    ).all()
)
# Out:
# True

# %%
profit_check = (
    transactions["net_sales"]
    - transactions["cost_amount"]
).round(2)

print(
    np.isclose(
        transactions["profit_amount"],
        profit_check
    ).all()
)
# Out:
# True

# %%
transactions[
    [
        "gross_sales",
        "discount_amount",
        "net_sales",
        "cost_amount",
        "profit_amount"
    ]
].sum()
# Out:
# gross_sales        7.561939e+08
# discount_amount    3.776759e+07
# net_sales          7.184264e+08
# cost_amount        5.492506e+08
# profit_amount      1.691758e+08
# dtype: float64

# %%
sales_path = RAW_DIR / "fact_sales.csv"

transactions.to_csv(
    sales_path,
    index=False
)

print(f"Saved: {sales_path}")
# Out:
# Saved: d:\GitHub\retail_data_quality_project\data\raw\fact_sales.csv

# %%
baseline_path = RAW_DIR / "fact_sales_clean_baseline.csv"

transactions.to_csv(
    baseline_path,
    index=False
)

print(f"Clean baseline saved: {baseline_path}")
# Out:
# Clean baseline saved: d:\GitHub\retail_data_quality_project\data\raw\fact_sales_clean_baseline.csv

# %%
messy_sales = transactions.copy()

print("Original rows:", len(messy_sales))
# Out:
# Original rows: 120000

# %%
rng = np.random.default_rng(42)

# %%
corruption_log = []

# %%
n_missing_customer = int(len(messy_sales) * 0.005)

missing_customer_idx = rng.choice(
    messy_sales.index,
    size=n_missing_customer,
    replace=False
)

messy_sales.loc[
    missing_customer_idx,
    "customer_id"
] = np.nan

corruption_log.append({
    "issue": "Missing customer_id",
    "records_affected": n_missing_customer
})

# %%
n_missing_payment = int(len(messy_sales) * 0.003)

missing_payment_idx = rng.choice(
    messy_sales.index,
    size=n_missing_payment,
    replace=False
)

messy_sales.loc[
    missing_payment_idx,
    "payment_method"
] = np.nan

corruption_log.append({
    "issue": "Missing payment_method",
    "records_affected": n_missing_payment
})

# %%
n_duplicates = int(len(messy_sales) * 0.004)

duplicate_rows = messy_sales.sample(
    n=n_duplicates,
    random_state=42
)

messy_sales = pd.concat(
    [messy_sales, duplicate_rows],
    ignore_index=True
)

corruption_log.append({
    "issue": "Exact duplicate transactions",
    "records_affected": n_duplicates
})

# %%
n_duplicate_ids = 200

duplicate_id_source = messy_sales.sample(
    n=n_duplicate_ids,
    random_state=100
)

# %%
duplicate_id_rows = duplicate_id_source.copy()

duplicate_id_rows["quantity"] = (
    duplicate_id_rows["quantity"] + 1
)

duplicate_id_rows["gross_sales"] = (
    duplicate_id_rows["quantity"]
    * duplicate_id_rows["unit_price"]
).round(2)

duplicate_id_rows["net_sales"] = (
    duplicate_id_rows["gross_sales"]
    - duplicate_id_rows["discount_amount"]
).round(2)

duplicate_id_rows["cost_amount"] = (
    duplicate_id_rows["quantity"]
    * duplicate_id_rows["unit_cost"]
).round(2)

duplicate_id_rows["profit_amount"] = (
    duplicate_id_rows["net_sales"]
    - duplicate_id_rows["cost_amount"]
).round(2)

# %%
messy_sales = pd.concat(
    [messy_sales, duplicate_id_rows],
    ignore_index=True
)

corruption_log.append({
    "issue": "Duplicate transaction IDs",
    "records_affected": n_duplicate_ids
})

# %%
n_negative_qty = 300

negative_qty_idx = rng.choice(
    messy_sales.index,
    size=n_negative_qty,
    replace=False
)

messy_sales.loc[
    negative_qty_idx,
    "quantity"
] = -messy_sales.loc[
    negative_qty_idx,
    "quantity"
].abs()

corruption_log.append({
    "issue": "Negative quantity",
    "records_affected": n_negative_qty
})

# %%
n_zero_qty = 200

zero_qty_idx = rng.choice(
    messy_sales.index,
    size=n_zero_qty,
    replace=False
)

messy_sales.loc[
    zero_qty_idx,
    "quantity"
] = 0

corruption_log.append({
    "issue": "Zero quantity",
    "records_affected": n_zero_qty
})

# %%
n_negative_price = 150

negative_price_idx = rng.choice(
    messy_sales.index,
    size=n_negative_price,
    replace=False
)

messy_sales.loc[
    negative_price_idx,
    "unit_price"
] = -messy_sales.loc[
    negative_price_idx,
    "unit_price"
].abs()

corruption_log.append({
    "issue": "Negative unit price",
    "records_affected": n_negative_price
})

# %%
n_invalid_discount = 200

invalid_discount_idx = rng.choice(
    messy_sales.index,
    size=n_invalid_discount,
    replace=False
)

messy_sales.loc[
    invalid_discount_idx,
    "discount_amount"
] = (
    messy_sales.loc[
        invalid_discount_idx,
        "gross_sales"
    ].abs()
    * rng.uniform(1.10, 1.50, size=n_invalid_discount)
).round(2)

corruption_log.append({
    "issue": "Discount greater than gross sales",
    "records_affected": n_invalid_discount
})

# %%
n_wrong_gross_sales = 250

wrong_gross_idx = rng.choice(
    messy_sales.index,
    size=n_wrong_gross_sales,
    replace=False
)

messy_sales.loc[
    wrong_gross_idx,
    "gross_sales"
] = (
    messy_sales.loc[
        wrong_gross_idx,
        "gross_sales"
    ] * 1.10
).round(2)

corruption_log.append({
    "issue": "Incorrect gross_sales calculation",
    "records_affected": n_wrong_gross_sales
})

# %%
n_wrong_profit = 250

wrong_profit_idx = rng.choice(
    messy_sales.index,
    size=n_wrong_profit,
    replace=False
)

messy_sales.loc[
    wrong_profit_idx,
    "profit_amount"
] = (
    messy_sales.loc[
        wrong_profit_idx,
        "profit_amount"
    ] * 0.80
).round(2)

corruption_log.append({
    "issue": "Incorrect profit calculation",
    "records_affected": n_wrong_profit
})

# %%
n_future_dates = 100

future_idx = rng.choice(
    messy_sales.index,
    size=n_future_dates,
    replace=False
)

future_dates = pd.date_range(
    start="2026-01-01",
    end="2026-12-31",
    periods=n_future_dates
)

messy_sales.loc[
    future_idx,
    "transaction_date"
] = future_dates

corruption_log.append({
    "issue": "Future transaction date",
    "records_affected": n_future_dates
})

# %%
n_missing_dates = 150

missing_date_idx = rng.choice(
    messy_sales.index,
    size=n_missing_dates,
    replace=False
)

messy_sales.loc[
    missing_date_idx,
    "transaction_date"
] = np.nan

corruption_log.append({
    "issue": "Missing transaction date",
    "records_affected": n_missing_dates
})

# %%
n_orphan_products = 150

orphan_product_idx = rng.choice(
    messy_sales.index,
    size=n_orphan_products,
    replace=False
)

messy_sales.loc[
    orphan_product_idx,
    "product_id"
] = [
    f"P9{rng.integers(100, 999)}"
    for _ in range(n_orphan_products)
]

corruption_log.append({
    "issue": "Orphan product ID",
    "records_affected": n_orphan_products
})

# %%
n_orphan_customers = 150

orphan_customer_idx = rng.choice(
    messy_sales.index,
    size=n_orphan_customers,
    replace=False
)

messy_sales.loc[
    orphan_customer_idx,
    "customer_id"
] = [
    f"C9{rng.integers(10000, 99999)}"
    for _ in range(n_orphan_customers)
]

corruption_log.append({
    "issue": "Orphan customer ID",
    "records_affected": n_orphan_customers
})

# %%
n_orphan_stores = 100

orphan_store_idx = rng.choice(
    messy_sales.index,
    size=n_orphan_stores,
    replace=False
)

messy_sales.loc[
    orphan_store_idx,
    "store_id"
] = [
    f"S{rng.integers(900, 999)}"
    for _ in range(n_orphan_stores)
]

corruption_log.append({
    "issue": "Orphan store ID",
    "records_affected": n_orphan_stores
})

# %%
n_text_prices = 100

text_price_idx = rng.choice(
    messy_sales.index,
    size=n_text_prices,
    replace=False
)

messy_sales.loc[
    text_price_idx,
    "unit_price"
] = (
    "SAR "
    + messy_sales.loc[
        text_price_idx,
        "unit_price"
    ].abs().round(2).astype(str)
)

corruption_log.append({
    "issue": "Unit price stored as text/currency string",
    "records_affected": n_text_prices
})
# Out:
# ---------------------------------------------------------------------------
# LossySetitemError                         Traceback (most recent call last)
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1115, in Block.setitem(self, indexer, value)
#    1114 try:
# -> 1115     casted = np_can_hold_element(values.dtype, value)
#    1116 except LossySetitemError:
#    1117     # current dtype cannot store value, coerce to common dtype
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\dtypes\cast.py:1775, in np_can_hold_element(dtype, element)
#    1773 if tipo.kind not in "iuf":
#    1774     # Anything other than float/integer we cannot hold
# -> 1775     raise LossySetitemError
#    1776 if not isinstance(tipo, np.dtype):
#    1777     # i.e. nullable IntegerDtype or FloatingDtype;
#    1778     #  we can put this into an ndarray losslessly iff it has no NAs
#
# LossySetitemError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 9
#       5     size=n_text_prices,
#       6     replace=False
#       7 )
#       8
# ----> 9 messy_sales.loc[
#      10     text_price_idx,
#      11     "unit_price"
#      12 ] = (
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
#    1952     # We have to operate column-wise
# -> 1953     self._setitem_with_indexer_split_path(indexer, value, name)
#    1954 else:
#    1955     self._setitem_single_block(indexer, value, name)
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\indexing.py:1997, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1993     self._setitem_with_indexer_2d_value(indexer, value)
#    1995 elif len(ilocs) == 1 and lplane_indexer == len(value) and not is_scalar(pi):
#    1996     # We are setting multiple rows in a single column.
# -> 1997     self._setitem_single_column(ilocs[0], value, pi)
#    1999 elif len(ilocs) == 1 and 0 != lplane_indexer != len(value):
#    2000     # We are trying to set N values into M entries of a single
#    2001     #  column, which is invalid for N != M
#    2002     # Exclude zero-len for e.g. boolean masking that is all-false
#    2004     if len(value) == 1 and not is_integer(info_axis):
#    2005         # This is a case like df.iloc[:3, [1]] = [0]
#    2006         #  where we treat as df.iloc[:3, 1] = 0
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\indexing.py:2181, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2171 if dtype == np.void:
#    2172     # This means we're expanding, with multiple columns, e.g.
#    2173     #     df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
#    (...)   2176     # Here, we replace those temporary `np.void` columns with
#    2177     # columns of the appropriate dtype, based on `value`.
#    2178     self.obj.iloc[:, loc] = construct_1d_array_from_inferred_fill_value(
#    2179         value, len(self.obj)
#    2180     )
# -> 2181 self.obj._mgr.column_setitem(loc, plane_indexer, value)
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\internals\managers.py:1541, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1539     col_mgr.setitem_inplace(idx, value)
#    1540 else:
# -> 1541     new_mgr = col_mgr.setitem((idx,), value)
#    1542     self.iset(loc, new_mgr._block.values, inplace=True)
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\internals\managers.py:620, in BaseBlockManager.setitem(self, indexer, value)
#     616     # No need to split if we either set all columns or on a single block
#     617     # manager
#     618     self = self.copy(deep=True)
# --> 620 return self.apply("setitem", indexer=indexer, value=value)
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1118, in Block.setitem(self, indexer, value)
#    1115     casted = np_can_hold_element(values.dtype, value)
#    1116 except LossySetitemError:
#    1117     # current dtype cannot store value, coerce to common dtype
# -> 1118     nb = self.coerce_to_target_dtype(value, raise_on_upcast=True)
#    1119     return nb.setitem(indexer, value)
#    1120 else:
#
# File d:\GitHub\retail_data_quality_project\.venv\Lib\site-packages\pandas\core\internals\blocks.py:468, in Block.coerce_to_target_dtype(self, other, raise_on_upcast)
#     465     raise_on_upcast = False
#     467 if raise_on_upcast:
# --> 468     raise TypeError(f"Invalid value '{other}' for dtype '{self.values.dtype}'")
#     469 if self.values.dtype == new_dtype:
#     470     raise AssertionError(
#     471         f"Did not expect new dtype {new_dtype} to equal self.dtype "
#     472         f"{self.values.dtype}. Please report a bug at "
#     473         "https://github.com/pandas-dev/pandas/issues."
#     474     )
#
# TypeError: Invalid value '<StringArray>
# ['SAR 2573.73', 'SAR 2376.91', 'SAR 2773.41', 'SAR 4812.98', 'SAR 1690.54',
#   'SAR 287.37', 'SAR 2422.12',  'SAR 305.59', 'SAR 1354.98',  'SAR 436.21',
#  'SAR 2032.58', 'SAR 3114.68', 'SAR 2022.03', 'SAR 4148.33', 'SAR 1856.18',
#  'SAR 2918.44', 'SAR 2232.89', 'SAR 2994.01', 'SAR 2918.73',  'SAR 556.35',
#  'SAR 3633.09', 'SAR 2767.68',  'SAR 639.33', 'SAR 4212.48',  'SAR 610.31',
#   'SAR 855.27', 'SAR 3118.32', 'SAR 3268.03', 'SAR 3454.18',  'SAR 628.52',
#  'SAR 2089.93', 'SAR 3049.27', 'SAR 2208.04',   'SAR 845.9',   'SAR 55.01',
#  'SAR 1975.98', 'SAR 3467.71', 'SAR 2410.73',  'SAR 532.76',  'SAR 481.46',
#  'SAR 1602.49', 'SAR 3435.27',  'SAR 4573.5',   'SAR 88.94', 'SAR 1692.68',
#  'SAR 3080.51', 'SAR 1632.58',  'SAR 653.22',  'SAR 679.26', 'SAR 4353.91',
#   'SAR 1514.7',  'SAR 395.14', 'SAR 2745.42', 'SAR 3409.79', 'SAR 4066.68',
#  'SAR 1014.99', 'SAR 2751.68', 'SAR 2542.56', 'SAR 3840.74',  'SAR 188.16',
#  'SAR 1662.28',  'SAR 360.45',  'SAR 521.71',  'SAR 310.88',  'SAR 406.77',
#   'SAR 566.43', 'SAR 1433.65',  'SAR 545.14', 'SAR 4320.68',  'SAR 983.34',
#   'SAR 873.35', 'SAR 2463.08', 'SAR 3482.61', 'SAR 3298.56', 'SAR 4023.87',
#  'SAR 1361.94', 'SAR 2583.27',  'SAR 600.29',  'SAR 198.93', 'SAR 2246.24',
#  'SAR 3897.41', 'SAR 4461.21',  'SAR 491.96', 'SAR 1488.37',   'SAR 56.93',
#  'SAR 2995.85', 'SAR 2420.28', 'SAR 3630.21', 'SAR 1554.44',  'SAR 3335.1',
#   'SAR 786.71',  'SAR 447.14', 'SAR 2639.27', 'SAR 2728.47', 'SAR 4126.39',
#  'SAR 1200.69', 'SAR 1291.43',  'SAR 2416.2',  'SAR 3539.7',  'SAR 1429.6']
# Length: 100, dtype: str' for dtype 'float64'

# %%
category_lookup = dim_product[
    ["product_id", "category"]
].drop_duplicates()

messy_sales = messy_sales.merge(
    category_lookup,
    on="product_id",
    how="left"
)

# %%
category_variants = {
    "Electronics": ["Electronics", "electronics", "ELECTRONICS", "Electronic"],
    "Home Appliances": ["Home Appliances", "home appliances", "HOME APPLIANCES"],
    "Fashion": ["Fashion", "fashion", "FASHION"],
    "Beauty": ["Beauty", "beauty", "BEAUTY"],
    "Sports": ["Sports", "sports", "SPORT"],
    "Grocery": ["Grocery", "grocery", "GROCERY"],
    "Home & Living": ["Home & Living", "home & living", "HOME & LIVING"]
}

# %%
n_inconsistent_categories = 500

category_idx = rng.choice(
    messy_sales.index,
    size=n_inconsistent_categories,
    replace=False
)

for idx in category_idx:
    current_category = messy_sales.loc[idx, "category"]

    if current_category in category_variants:
        messy_sales.loc[idx, "category"] = rng.choice(
            category_variants[current_category]
        )

corruption_log.append({
    "issue": "Inconsistent category formatting",
    "records_affected": n_inconsistent_categories
})

# %%
corruption_report = pd.DataFrame(corruption_log)

corruption_report
# Out:
#                                 issue  records_affected
# 0                 Missing customer_id               600
# 1              Missing payment_method               360
# 2        Exact duplicate transactions               480
# 3           Duplicate transaction IDs               200
# 4                   Negative quantity               300
# 5                       Zero quantity               200
# 6                 Negative unit price               150
# 7   Discount greater than gross sales               200
# 8   Incorrect gross_sales calculation               250
# 9        Incorrect profit calculation               250
# 10            Future transaction date               100
# 11           Missing transaction date               150
# 12                  Orphan product ID               150
# 13                 Orphan customer ID               150
# 14                    Orphan store ID               100
# 15   Inconsistent category formatting               500

# %%
messy_sales_path = RAW_DIR / "fact_sales.csv"

messy_sales.to_csv(
    messy_sales_path,
    index=False
)

print(f"Messy raw sales saved: {messy_sales_path}")
# Out:
# Messy raw sales saved: d:\GitHub\retail_data_quality_project\data\raw\fact_sales.csv
